# %% [markdown]
# (lab05)=
# # Lab 5 Worksheet

# %% [markdown]
# ## Name, NetID, Collaborators
# Please edit the markdown cell below for “Names & NetIDs” and enter:
# - Your name and NetID (eg. cc5948), and
# - The names and NetIDs of everyone with whom you have collaborated with (e.g., discussed
# questions with, provided help to, received help from, etc.).
#
# Our goal is to create an honest, collaborative, and positive learning environment. Keep
# in mind that while collaboration in lab and homework is strongly encouraged, the work
# you submitted must be your own (you typed them up yourself; you can explain what you
# submitted). Your goal is to use the help and support to eventually understand the ideas
# and the methods yourself

# %% [markdown]
# **Name and NetID:**
#
#
# **Collaborators:**

# %% [markdown]
# ## Part 1: Functions

# %% [markdown]
# ### Exercise 1: Cancer model
#
# In Lesson 9, we built the following if-statement that classified a lump as either cancerous or benign based on its clump thickness and marginal adhesion (Slide 7.2).
#
# <pre><code>
# if ( Adhesion &gt; 4 ) {
#     Class &lt;- 1
# } else if (Thickness &gt; 6) {
#     Class &lt;- 1
# } else {
#     Class &lt;- 0
# }
# Class
# </code></pre>
#
# - Build a function that uses this if-statement to determine a class of a lump.
# - Apply the function to the points marked on the plot below (approximate the coordinates). Does the classification given by the function align with the one you did by hand?
#
# <img src='../img/L09_cancer_plot.png' alt='scatter plot of marginal adhesion vs clump thickness' width=400>

# %% [markdown]
# ### Exercise 2: Temperature conversion again
# On Homework 1, you used the following formula to convert a temperature $f$ in degrees Fahrenheit to the equivalent temperature $c$ in degrees Celsius.
#
# $$(f − 32) \cdot \frac{5}{9} = c$$
#
# - Create a function called `F_to_C` that does this conversion.
# - Test your function on the following known values.
#
#
# | Degrees Fahrenheit | Degrees Celsius | Significance                   |
# |--------------------|-----------------|--------------------------------|
# | 32                 | 0               | Freezing point of water        |
# | 212                | 100             | Boiling point of water         |
# | 97.5               | 36.39           | Average Human body temperature |

# %% [markdown]
# ## Part 2: Hailstones

# %% [markdown]
# ### Exercise 3: Hailstone rules
#
# A sequence of hailstone numbers is generated by repeatedly applying the following two rules.
# 1. If the number is even, then divide it by two.
# 2. If the number is odd, then multiply it by three and add 1.
#
# - Write an if-else statement that implements these rules on a numerical variable `n`.

# %% [markdown]
# ### Exercise 4: Hailstone function
#
# - Wrap your if-else statement in a function called `hailstone`.
# - Verify that your `hailstone()` function produces the expected result for the following values of `n`.
#
# | **n**      | 3  | 4 | 5  | 6 |
# |------------|----|---|----|---|
# | **result** | 10 | 2 | 16 | 3 |

# %% [markdown]
# ### Exercise 5: Hailstone sequence
#
# If you load the `dplyr` package, you can use piping with your custom functions too. For a function with a single input this looks like `INPUT %>% FUNCTION()`.
#
# A hailstone sequence is built by picking a seed number, applying the hailstone function to it and then applying the hailstone function to the resulting output. Each subsequent number is produced by feeding the previous number into the hailstone function.
#
# - Use `hailstone()` to produce the first seven numbers in the hailstone sequence seeded by 3.
# - Verify that your code outputs the following seven numbers: 10, 5, 16, 8, 4, 2, 1
